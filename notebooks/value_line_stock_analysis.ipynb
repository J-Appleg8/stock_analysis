# %% [markdown]
# ## <span style="color:turquoise">Value Line: Stock Analysis</span>
#
# ---

# %% [markdown]
# ### <span style="color:mediumspringgreen">Value Stocks</span>

# %%
import pandas as pd

stock_data = '../files/Value Screen.xlsx'

value_stocks_df = pd.read_excel(stock_data)

value_stocks_df
# Out:
#                 Company Ticker  Stock Price  Market Cap $ (Mil)  \
# 0   Atlas Air Worldwide   AAWW       101.92             2890.86
# 1     Amer. Int'l Group    AIG        63.50            47448.21
# 2        Ally Financial   ALLY        32.67             9811.94
# 3        Amer. Woodmark   AMWD        53.31              886.12
# 4      Antero Resources     AR        29.26             8869.61
# ..                  ...    ...          ...                 ...
# 81       Westlake Corp.    WLK       116.25            14840.36
# 82         WestRock Co.    WRK        36.68             9331.39
# 83     U.S. Steel Corp.      X        28.79             6744.61
# 84    Exxon Mobil Corp.    XOM       113.21           466198.80
# 85       Zions Bancorp.   ZION        52.02             7782.76
#
#    Current PE Ratio  Current EPS Est EPS  Price to Book Value  \
# 0              7.15        14.25   14.95                 0.74
# 1              7.17         8.86   14.25                 0.63
# ...
